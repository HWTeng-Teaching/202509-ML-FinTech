# %% [markdown]
# (a)
#
# y = exp(beta0 + beta1 * x)
#
# log odds
#
# = ln(Pr(Y = orange) / Pr(Y = apple))
#
# = ln(Pr(Y = orange) / (1 - Pr(Y = orange)))
#
# = ln((y / (1 + y)) / (1 - (y / (1 + y))))
#
# = ln((y / (1 + y)) / (1 / (1 + y)))
#
# = ln(y)
#
# = ln(exp(beta0 + beta1 * x))
#
# = beta0 + beta1 * x

# %% [markdown]
# (b)
#
# y1 = exp(alpha_orange0 + alpha_orange1 * x)
#
# y2 = exp(alpha_apple0 + alpha_apple1 * x)
#
# log odds
#
# = ln(Pr(Y = orange) / Pr(Y = apple))
#
# = ln(Pr(Y = orange) / (1 - Pr(Y = orange)))
#
# = ln((y1 / (y1 + y2)) / (1 - (y1 / (y1 + y2))))
#
# = ln((y1 / (y1 + y2)) / (y2 / (y1 + y2)))
#
# = ln(y1 / y2)
#
# = ln(y1) - ln(y2)
#
# = ln(exp(alpha_orange0 + alpha_orange1 * x)) - ln(exp(alpha_apple0 + alpha_apple1 * x))
#
# = (alpha_orange0 + alpha_orange1 * x) - (alpha_apple0 + alpha_apple1 * x)
#
# = (alpha_orange0 - alpha_apple0) + (alpha_orange1 - alpha_apple1) * x

# %%
#(c)
beta_0_hat = 2
beta_1_hat = -1

alpha_apple_0_hat = 0
alpha_apple_1_hat = 0

alpha_orange_0_hat = beta_0_hat + alpha_apple_0_hat
alpha_orange_1_hat = beta_1_hat + alpha_apple_1_hat

print(f"coefficient estimates (beta_0, beta_1): ({beta_0_hat}, {beta_1_hat})")

print("\nSuppose apple to be 0：\n")
print(f"Alpha_apple_0: {0}")
print(f"Alpha_apple_1: {0}")
print(f"Alpha_orange_0: {alpha_orange_0_hat}")
print(f"Alpha_orange_1: {alpha_orange_1_hat}")

alpha_orange_0_hat = 0
alpha_orange_1_hat = 0

alpha_apple_0_hat = alpha_orange_0_hat - beta_0_hat
alpha_apple_1_hat = alpha_orange_1_hat - beta_1_hat

print("\nSuppose orange to be 0：\n")
print(f"Alpha_apple_0: {alpha_apple_0_hat}")
print(f"Alpha_apple_1: {alpha_apple_1_hat}")
print(f"Alpha_orange_0: {0}")
print(f"Alpha_orange_1: {0}")
# Out:
# coefficient estimates (beta_0, beta_1): (2, -1)
#
# Suppose apple to be 0：
#
# Alpha_apple_0: 0
# Alpha_apple_1: 0
# Alpha_orange_0: 2
# Alpha_orange_1: -1
#
# Suppose orange to be 0：
#
# Alpha_apple_0: -2
# Alpha_apple_1: 1
# Alpha_orange_0: 0
# Alpha_orange_1: 0

# %%
#(d)
alpha_orange_0_hat = 1.2
alpha_orange_1_hat = -2
alpha_apple_0_hat = 3.0
alpha_apple_1_hat = 0.6

beta_0_hat = alpha_orange_0_hat - alpha_apple_0_hat
beta_1_hat = alpha_orange_1_hat - alpha_apple_1_hat

print(f"coefficient estimates:")
print(f"Beta_0 (intercept): {beta_0_hat:.1f}")
print(f"Beta_1 (X coefficient): {beta_1_hat:.1f}")

# 最終結果展示
print(f"\nβ̂₀ = {beta_0_hat:.1f}, β̂₁ = {beta_1_hat:.1f}")
# Out:
# coefficient estimates:
# Beta_0 (intercept): -1.8
# Beta_1 (X coefficient): -2.6
#
# β̂₀ = -1.8, β̂₁ = -2.6

# %% [markdown]
# (e)
#
# 100%
#
# The two models (Standard Logistic Regression and Softmax for two classes) are mathematically equivalent in a binary setting. When fitted to the same data, they calculate the exact same probabilities for every observation. Since the probabilities are the same, they will always make the exact same final classification decision
