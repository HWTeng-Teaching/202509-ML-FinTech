# %% [markdown]
# 9. This problem has to do with odds.

# %% [markdown]
# (a) On average, what fraction of people with an odds of 0.37 of defaulting on their credit card payment will in fact default?

# %%
odd_a = 0.37

probability_a = odd_a / (1 + odd_a)

print(f"{probability_a * 100:.2f}% of people with an odds of 0.37 of defaulting on their credit card payment will in fact default")
# Out:
# 27.01% of people with an odds of 0.37 of defaulting on their credit card payment will in fact default

# %% [markdown]
# (b) Suppose that an individual has a 16% chance of defaulting on her credit card payment. What are the odds that she will de-fault?

# %%
probability_b = 0.16

odd_b = probability_b / (1 - probability_b)

print(f"she will default with an odds of: {odd_b:.4f}")
# Out:
# she will default with an odds of: 0.1905
