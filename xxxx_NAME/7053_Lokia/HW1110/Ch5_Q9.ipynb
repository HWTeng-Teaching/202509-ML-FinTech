# %% [markdown]
# We will now consider the Boston housing data set, from the ISLP
# library.

# %% [markdown]
# (a) Based on this data set, provide an estimate for the population
# mean of medv. Call this estimate µˆ.

# %%
# !pip install ISLP
from ISLP import load_data
import pandas as pd
import numpy as np

boston = load_data('Boston')
boston.head()
# Out:
# ...
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
medv = boston["medv"].values
n = len(medv)

print("Number of data entries n =", n)

mu_hat = medv.mean()
print("\n(a) Sample average μ̂ =", mu_hat)
# Out:
# Number of data entries n = 506
#
# (a) Sample average μ̂ = 22.532806324110677

# %% [markdown]
# (b) Provide an estimate of the standard error of µˆ. Interpret this
# result.
# Hint: We can compute the standard error of the sample mean by
# dividing the sample standard deviation by the square root of the
# number of observations.

# %%
s = medv.std(ddof=1)
se_mu = s / np.sqrt(n)

print("\n(b) Sample standard deviation s =", s)
print("Standard error of the mean SE(μ̂) =", se_mu)
# Out:
# (b) Sample standard deviation s = 9.197104087379818
# Standard error of the mean SE(μ̂) = 0.40886114749753505

# %% [markdown]
# (c) Now estimate the standard error of µˆ using the bootstrap. How
# does this compare to your answer from (b)?

# %%
def bootstrap_stat(x, B=10000, stat_func=np.mean, random_state=0):
    rng = np.random.default_rng(random_state)
    n = len(x)
    boot = np.empty(B)
    for b in range(B):
        sample = rng.choice(x, size=n, replace=True)
        boot[b] = stat_func(sample)
    return boot

B = 10000
boot_means = bootstrap_stat(medv, B=B, stat_func=np.mean)
boot_se_mu = boot_means.std(ddof=1)

print("\n(c) Bootstrap estimate SE(μ̂) =", boot_se_mu)
print("Difference from (b) =", boot_se_mu - se_mu)
# Out:
# (c) Bootstrap estimate SE(μ̂) = 0.4111267216210197
# Difference from (b) = 0.0022655741234846594

# %% [markdown]
# (d) Based on your bootstrap estimate from (c), provide a 95 % confidence interval for the mean of medv. Compare it to the results
# obtained by using Boston['medv'].std() and the two standard
# error rule (3.9).
# Hint: You can approximate a 95 % confidence interval using the
# formula [ˆµ − 2SE(ˆµ), µˆ + 2SE(ˆµ)].

# %%
ci_lower_boot = np.percentile(boot_means, 2.5)
ci_upper_boot = np.percentile(boot_means, 97.5)

print("\n(d) Bootstrap percentile method 95% CI = [{:.3f}, {:.3f}]"
      .format(ci_lower_boot, ci_upper_boot))

ci_lower_2se = mu_hat - 2 * se_mu
ci_upper_2se = mu_hat + 2 * se_mu

print("    Two-SE rule 95% CI   = [{:.3f}, {:.3f}]"
      .format(ci_lower_2se, ci_upper_2se))
# Out:
# (d) Bootstrap percentile method 95% CI = [21.737, 23.368]
#     Two-SE rule 95% CI   = [21.715, 23.351]

# %% [markdown]
# (e) Based on this data set, provide an estimate, µˆmed, for the median
# value of medv in the population.

# %%
mu_med_hat = np.median(medv)
print("\n(e) Sample median μ̂_med =", mu_med_hat)
# Out:
# (e) Sample median μ̂_med = 21.2

# %% [markdown]
# (f) We now would like to estimate the standard error of µˆmed. Unfortunately, there is no simple formula for computing the standard
# error of the median. Instead, estimate the standard error of the
# median using the bootstrap. Comment on your findings.

# %%
boot_medians = bootstrap_stat(medv, B=B, stat_func=np.median)
boot_se_med = boot_medians.std(ddof=1)

print("\n(f) Bootstrap estimate SE(μ̂_med) =", boot_se_med)
print("Comparison: Average SE =", se_mu)
# Out:
# (f) Bootstrap estimate SE(μ̂_med) = 0.37689747302219584
# Comparison: Average SE = 0.40886114749753505

# %% [markdown]
# (g) Based on this data set, provide an estimate for the tenth percentile of medv in Boston census tracts. Call this quantity µˆ0.1.
# (You can use the np.percentile() function.)

# %%
mu_p10_hat = np.percentile(medv, 10)
print("\n(g) 10th percentile μ̂_0.1 =", mu_p10_hat)
# Out:
# (g) 10th percentile μ̂_0.1 = 12.75

# %% [markdown]
# (h) Use the bootstrap to estimate the standard error of µˆ0.1. Comment on your findings.

# %%
def perc_10(x):
    return np.percentile(x, 10)

boot_p10 = bootstrap_stat(medv, B=B, stat_func=perc_10)
boot_se_p10 = boot_p10.std(ddof=1)

print("\n(h) Bootstrap estimate SE(μ̂_0.1) =", boot_se_p10)
# Out:
# (h) Bootstrap estimate SE(μ̂_0.1) = 0.5035893213675798
