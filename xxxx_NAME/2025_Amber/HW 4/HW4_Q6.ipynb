# %% [markdown]
# Suppose we collect data for a group of students in a statistics class
# with variables $X_1=$ hours studied, $X_2=$ undergrad GPA, and $Y =$
# receive an A. We fit a logistic regression and produce estimated
# coefficient, $\hat{\beta}_0 = -6$, $\hat{\beta}_1 = 0.05$, $\hat{\beta}_2 = 1$.

# %% [markdown]
# (a) Estimate the probability that a student who studies for 40 h and
# has an undergrad GPA of 3.5 gets an A in the class.

# %% [markdown]
# Linear predictor:
# η = -6 + 0.05(40) + 1(3.5) = -6 + 2 + 3.5 = -0.5
#
# Convert to probability using logistic function p = e^η / (1 + e^η):
#
# p = e^(-0.5) / (1 + e^(-0.5))
# ≈ 1 / (1 + e^(0.5)) ≈ 1 / 2.6487 ≈ 0.3775

# %% [markdown]
# (b) How many hours would the student in part (a) need to study to
# have a 50 % chance of getting an A in the class?

# %% [markdown]
# For p = 0.5 → logit(0.5) = 0.
# Solve for X1:
#
# 0 = -6 + 0.05X1 + 1(3.5)
# → 0.05X1 = 2.5 → X1 = 2.5 / 0.05 = 50
