# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"/Users/ambervo/Library/CloudStorage/OneDrive-Personal/Documents/GMBA 3/FinTech/Textbook Dataset/ALL CSV FILES - 2nd Edition/College.csv")

# %%
df.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
df= df.rename(columns={'Unnamed: 0':'College'})

# %%
df.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
df.dtypes
# Out:
# College         object
# Private         object
# Apps             int64
# Accept           int64
# Enroll           int64
# Top10perc        int64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal         int64
# PhD              int64
# Terminal         int64
# S.F.Ratio      float64
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# dtype: object

# %%
missing_values_df = df.isnull()
missing_values_df.sum()
# Out:
# College        0
# Private        0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# dtype: int64

# %%
from pandas.plotting import scatter_matrix

# %%
df['Top10perc']
C=['Top10perc','Apps','Enroll']

# %%
df[C]
# Out:
#      Top10perc   Apps  Enroll
# 0           23   1660     721
# 1           16   2186     512
# 2           22   1428     336
# 3           60    417     137
# 4           16    193      55
# ..         ...    ...     ...
# 772          4   2197     543
# 773         24   1959     695
# 774         34   2097     695
# 775         95  10705    1317
# 776         28   2989     691
#
# [777 rows x 3 columns]

# %%
pd.plotting.scatter_matrix(df[C], figsize=(8, 8))
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
df.boxplot(column='Outstate',by='Private',figsize=(6,6))
plt.ylabel('Out-of-state Tuition')
plt.show()

# %%
df['Elite']=pd.cut(df['Top10perc'],bins=[0,50,100],labels=['No','Yes'])
print(df['Elite'].value_counts())
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
df.boxplot(column='Outstate',by='Elite',figsize=(6,6))
plt.ylabel('Outstate Tuition')
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

df['Apps'].plot.hist(bins=20, ax=axes[0,0], title='Applications')
df['Accept'].plot.hist(bins=20, ax=axes[0,1],title='Acceptances')
df['Enroll'].plot.hist(bins=20, ax=axes[1,0],title='Enrollments')
df['Outstate'].plot.hist(bins=20, ax=axes[1,1],title='Outstate Tuition')
plt.tight_layout()
plt.show()

# %%
df.describe(include='all')
# Out:
#                              College Private          Apps        Accept  \
# count                            777     777    777.000000    777.000000
# unique                           777       2           NaN           NaN
# top     Abilene Christian University     Yes           NaN           NaN
# freq                               1     565           NaN           NaN
# mean                             NaN     NaN   3001.638353   2018.804376
# std                              NaN     NaN   3870.201484   2451.113971
# min                              NaN     NaN     81.000000     72.000000
# 25%                              NaN     NaN    776.000000    604.000000
# 50%                              NaN     NaN   1558.000000   1110.000000
# 75%                              NaN     NaN   3624.000000   2424.000000
# max                              NaN     NaN  48094.000000  26330.000000
#
#              Enroll   Top10perc   Top25perc   F.Undergrad   P.Undergrad  \
# ...

# %%
df.groupby('Private')['Grad.Rate'].mean().plot(kind='bar', figsize=(6,6))
plt.ylabel('Graduation Rate by Private/Public Colleges')
plt.show()

# %%
df['Grad.Rate'].plot.hist(bins=20, figsize=(6,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot(column='Grad.Rate', by='Private')
df.boxplot(column='S.F.Ratio', by='Private')
# Out:
# <Axes: title={'center': 'S.F.Ratio'}, xlabel='Private'>

# %%
df.groupby('Elite', observed=True)['Outstate'].mean()
df.groupby('Elite', observed=True)['Grad.Rate'].mean()
# Out:
# Elite
# No     63.463519
# Yes    83.384615
# Name: Grad.Rate, dtype: float64

# %%
df['AcceptRate'] = df['Accept'] / df['Apps']
df['EnrollRate'] = df['Enroll'] / df['Accept']

# %%
df['AcceptRate'].mean()
# Out:
# np.float64(0.7469277072775414)

# %%
df['EnrollRate'].mean()
# Out:
# np.float64(0.41201469046890854)

# %%
sns.scatterplot(x='Apps',y='Enroll',hue='Private',data=df)
# Out:
# <Axes: xlabel='Apps', ylabel='Enroll'>

# %%
df[['Apps','Accept','Enroll','Outstate','Grad.Rate']].boxplot(figsize=(10,6))
# Out:
# <Axes: >

# %%
sns.scatterplot(x='PhD',y='Grad.Rate',data=df)
sns.scatterplot(x='Terminal',y='Grad.Rate',data=df)
# Out:
# <Axes: xlabel='PhD', ylabel='Grad.Rate'>
