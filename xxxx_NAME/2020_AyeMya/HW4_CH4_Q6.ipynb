# %% [markdown]
# 6. Suppose we collect data for a group of students in a statistics class
#  with variables X1 =hours studied, X2=undergrad GPA, and Y =
#  receive an A. We fit a logistic regression and produce estimated
#  coefficient, ˆβ0 = −6, ˆβ1 = 0.05, ˆβ2 = 1.
#  (a) Estimate the probability that a student who studies for 40h and
#  has an undergrad GPA of 3.5 gets an A in the class.
#  (b) How many hours would the student in part (a) need to study to
#  have a 50% chance of getting an A in the class?

# %% [markdown]
# We collect data for students with:
# - \( X_1 = \) hours studied
# - \( X_2 = \) undergrad GPA
# - \( Y = 1 \) if the student receives an A, \(0\) otherwise
#
# We fit a logistic regression model:
#
# \[
# \Pr(Y = 1 \mid X_1, X_2)
# = \frac{\exp(\hat{\beta}_0 + \hat{\beta}_1 X_1 + \hat{\beta}_2 X_2)}{1 + \exp(\hat{\beta}_0 + \hat{\beta}_1 X_1 + \hat{\beta}_2 X_2)}
# \]
#
# Given:
# \[
# \hat{\beta}_0 = -6, \quad
# \hat{\beta}_1 = 0.05, \quad
# \hat{\beta}_2 = 1
# \]
#
# $$ p(x) = \frac{e^{\beta_0 + \beta_1x_1 + \beta_2x_2}}{1 + e^{\beta_0 + \beta_1x_1 + \beta_2x_2}} = \frac{e^{-6 + 0.05x_1 + x_2}}{1 + e^{-6 + 0.05x_1 + x_2}} $$
#
# (a)
# $$ => \frac{e^{-6 + 0.05 \times 40 + 3.5}}{1 + e^{-6 + 0.05 \times 40 + 3.5}} = 0.378$$

# %% [markdown]
# We want:
# \[
# p = 0.5
# \]
#
# For logistic regression,
# \[
# p = 0.5 \quad \Longleftrightarrow \quad \eta = 0
# \]
# because
# \[
# \frac{e^{0}}{1 + e^{0}} = \frac{1}{2} = 0.5
# \]
#
# So set the logit to 0 and solve for \( X_1 \) (hours studied):
#
# \[
# 0 = \hat{\beta}_0 + \hat{\beta}_1 X_1 + \hat{\beta}_2 X_2
# \]
#
# $$ \frac{1-p(x)}{p(x)} = e^{\beta_0 + \beta_1x_1 + \beta_2x_2} $$
# $$ \frac{1-0.5}{0.5} = e^{-6 + 0.05 \times h + 3.5} => -6 + 3.5 + 0.05 \times h = ln(1) = 0 => h = 50 \ \text{hours}$$
