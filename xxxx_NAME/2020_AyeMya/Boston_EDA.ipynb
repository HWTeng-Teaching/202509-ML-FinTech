# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly_express as px

# %%
df = pd.read_csv(r"D:\data_ML&Fintech\Boston.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio  lstat  medv
# 0  296     15.3   4.98  24.0
# 1  242     17.8   9.14  21.6
# 2  242     17.8   4.03  34.7
# 3  222     18.7   2.94  33.4
# 4  222     18.7   5.33  36.2

# %%
df= df.rename(columns={'Unnamed: 0':'No.'})

# %%
df.tail()
# Out:
#      No.     crim   zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 501  502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  505  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv RoomGroup
# 501     21.0   9.67  22.4       6–7
# 502     21.0   9.08  20.6       6–7
# 503     21.0   5.64  23.9       6–7
# 504     21.0   6.48  22.0       6–7
# 505     21.0   7.88  11.9       6–7

# %%
df.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# crim          float64
# zn            float64
# indus         float64
# chas            int64
# nox           float64
# rm            float64
# age           float64
# dis           float64
# rad             int64
# tax             int64
# ptratio       float64
# lstat         float64
# medv          float64
# dtype: object

# %%
df.shape
# Out:
# (506, 14)

# %%
sns.pairplot(df[['crim','tax','rm','lstat','medv']])
plt.show()

# %%
df.corr()['crim'].sort_values(ascending=False)
# Out:
# crim          1.000000
# rad           0.625505
# tax           0.582764
# lstat         0.455621
# nox           0.420972
# Unnamed: 0    0.407407
# indus         0.406583
# age           0.352734
# ptratio       0.289946
# chas         -0.055892
# zn           -0.200469
# rm           -0.219247
# dis          -0.379670
# medv         -0.388305
# Name: crim, dtype: float64

# %%
df['crim'].max(), df['tax'].max(), df['ptratio'].max()
# Out:
# (np.float64(88.9762), np.int64(711), np.float64(22.0))

# %%
df['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
df['ptratio'].median()
# Out:
# np.float64(19.05)

# %%
idx=df['medv'].idxmin()
df.loc[idx]
# Out:
# Unnamed: 0    399.0000
# crim           38.3518
# zn              0.0000
# indus          18.1000
# chas            0.0000
# nox             0.6930
# rm              5.4530
# age           100.0000
# dis             1.4896
# rad            24.0000
# tax           666.0000
# ptratio        20.2000
# lstat          30.5900
# medv            5.0000
# Name: 398, dtype: float64

# %%
more7= df[df['rm']>7].shape[0]
more7
# Out:
# 64

# %%
more8= df[df['rm']>8].shape[0]
more8
# Out:
# 13

# %%
df[df['rm']>8].sum()
# Out:
# Unnamed: 0    3020.00000
# crim             9.34434
# zn             177.00000
# indus           92.02000
# chas             2.00000
# nox              7.01010
# rm             108.53100
# age            930.00000
# dis             44.59250
# rad             97.00000
# tax           4226.00000
# ptratio        212.70000
# lstat           56.03000
# medv           574.60000
# dtype: float64

# %%
df.hist(figsize=(12, 10), bins=30)
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'crim'}>, <Axes: title={'center': 'zn'}>,
#         <Axes: title={'center': 'indus'}>],
#        [<Axes: title={'center': 'chas'}>,
#         <Axes: title={'center': 'nox'}>, <Axes: title={'center': 'rm'}>,
#         <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'dis'}>, <Axes: title={'center': 'rad'}>,
#         <Axes: title={'center': 'tax'}>,
#         <Axes: title={'center': 'ptratio'}>],
#        [<Axes: title={'center': 'lstat'}>,
#         <Axes: title={'center': 'medv'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", center=0)
plt.show()

# %%
sns.scatterplot(x='crim', y='medv', data=df)
sns.scatterplot(x='nox', y='medv', data=df)
# Out:
# <Axes: xlabel='crim', ylabel='medv'>

# %%
sns.scatterplot(x='age', y='medv', data=df)
# Out:
# <Axes: xlabel='age', ylabel='medv'>

# %%
sns.scatterplot(x='lstat', y='medv', data=df)
# Out:
# <Axes: xlabel='lstat', ylabel='medv'>

# %%
df[['crim','tax','ptratio','medv']].boxplot(figsize=(10,6))
# Out:
# <Axes: >

# %%
df.boxplot(column='medv', by='chas')
# Out:
# <Axes: title={'center': 'medv'}, xlabel='chas'>

# %%
df['RoomGroup'] = pd.cut(df['rm'], bins=[0,5,6,7,8,10], labels=['≤5','5–6','6–7','7–8','>8'])
df.groupby('RoomGroup')['medv'].mean()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_24316\2630387162.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('RoomGroup')['medv'].mean()
# RoomGroup
# ≤5     16.643750
# 5–6    17.551592
# 6–7    22.015985
# 7–8    36.917647
# >8     44.200000
# Name: medv, dtype: float64

# %%
df.nlargest(10, 'medv')
# Out:
#      Unnamed: 0     crim    zn  indus  chas     nox     rm   age     dis  rad  \
# 161         162  1.46336   0.0  19.58     0  0.6050  7.489  90.8  1.9709    5
# 162         163  1.83377   0.0  19.58     1  0.6050  7.802  98.2  2.0407    5
# 163         164  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5
# 166         167  2.01019   0.0  19.58     0  0.6050  7.929  96.2  2.0459    5
# 186         187  0.05602   0.0   2.46     0  0.4880  7.831  53.6  3.1992    3
# 195         196  0.01381  80.0   0.46     0  0.4220  7.875  32.0  5.6484    4
# 204         205  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4
# 225         226  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8
# 257         258  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5
# 267         268  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5
#
#      tax  ptratio  lstat  medv RoomGroup
# 161  403     14.7   1.73  50.0       7–8
# ...
