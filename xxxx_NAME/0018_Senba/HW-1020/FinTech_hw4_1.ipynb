# %% [markdown]
# # 6. Suppose we collect data for a group of students in a statistics class with variables X1 = hours studied, X2 = undergrad GPA, and Y = receive an A. We fit a logistic regression and produce estimated coefficients, β̂₀ = -6, β̂₁ = 0.05, and β̂₂ = 1.
#
# ## 邏輯迴歸模型
# $$\text{logit}(\hat{P}) = \ln\left(\frac{\hat{P}}{1-\hat{P}}\right) = \hat{\beta}_0 + \hat{\beta}_1 X_1 + \hat{\beta}_2 X_2$$
#
# $$\hat{P} = \frac{e^{\hat{\beta}_0 + \hat{\beta}_1 X_1 + \hat{\beta}_2 X_2}}{1 + e^{\hat{\beta}_0 + \hat{\beta}_1 X_1 + \hat{\beta}_2 X_2}}$$

# %% [markdown]
# ## (a) Estimate the probability that a student who studies for 40 h and has an undergrad GPA of 3.5 gets an A in the class.

# %%
import numpy as np

# %%
beta_0_hat = -6
beta_1_hat = 0.05
beta_2_hat = 1

X1 = 40
X2 = 3.5

eta_hat = beta_0_hat + (beta_1_hat * X1) + (beta_2_hat * X2)

P_hat = np.exp(eta_hat) / (1 + np.exp(eta_hat))

# 顯示結果
print(f"時數 (X1): {X1}")
print(f"GPA (X2): {X2}")
print(f"線性預測值 (η̂): {eta_hat:.4f}")
print(f"估計 A 的概率: {P_hat * 100:.2f}%")
# Out:
# 時數 (X1): 40
# GPA (X2): 3.5
# 線性預測值 (η̂): -0.5000
# 估計 A 的概率: 37.75%

# %% [markdown]
# ## (b) How many hours would the student in part (a) need to study to have a 50 % chance of getting an A in the class?

# %%
beta_0_hat = -6
beta_1_hat = 0.05
beta_2_hat = 1

X2 = 3.5
target_eta = 0

X1_required = (-beta_0_hat - (beta_2_hat * X2)) / beta_1_hat

print(f"GPA (X2): {X2}")
print(f"為了達到 50% 概率所需的時數（X1）: {X1_required:.2f} 小時")
# Out:
# GPA (X2): 3.5
# 為了達到 50% 概率所需的時數（X1）: 50.00 小時
