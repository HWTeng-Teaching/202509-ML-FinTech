# %% [markdown]
# # 9.  This problem has to do with odds.

# %% [markdown]
# ## (a) On average, what fraction of people with an odds of 0.37 of defaulting on their credit card payment will in fact default?
#
# $$\text{Fraction (Probability)} = P = \frac{\text{Odds}}{1 + \text{Odds}}$$

# %%
odds_a = 0.37

probability_a = odds_a / (1 + odds_a)

print(f"幾率 (Odds): {odds_a}")
print(f"違約概率 (P): {probability_a:.4f}")
print(f"\n大約 {probability_a * 100:.2f}% 的人會違約。")
# Out:
# 幾率 (Odds): 0.37
# 違約概率 (P): 0.2701
#
# 大約 27.01% 的人會違約。

# %% [markdown]
# ## (b) Suppose that an individual has a 16 % chance of defaulting on her credit card payment. What are the odds that she will default?
#
# $$\text{Odds} = \frac{P}{1 - P}$$

# %%
probability_b = 0.16

odds_b = probability_b / (1 - probability_b)

print(f"違約概率 (P): {probability_b}")
print(f"違約幾率 (Odds): {odds_b:.4f}")
# Out:
# 違約概率 (P): 0.16
# 違約幾率 (Odds): 0.1905
