# %% [markdown]
# ## 4. This question relates to the plots in Figure
# ![9-2.png](data:image/png;base64,...)

# %% [markdown]
# ## (a) Sketch the tree corresponding to the partition of the predictor space illustrated in the left-hand panel of Figure. The numbers inside the boxes indicate the mean of Y within each region.
# ![9-2-1.png](data:image/png;base64,...)

# %% [markdown]
# ## (b) Create a diagram similar to the left-hand panel of Figure, using the tree illustrated in the right-hand panel of the same fgure. You should divide up the predictor space into the correct regions, and indicate the mean for each region.![9-2-2.png](data:image/png;base64,...)
