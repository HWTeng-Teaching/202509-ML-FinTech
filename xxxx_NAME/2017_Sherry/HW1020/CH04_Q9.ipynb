# %% [markdown]
# # CH04_Q9

# %% [markdown]
# ### This problem has to do with *odds*.

# %% [markdown]
# ###(a) On average, what fraction of people with an odds of 0.37 of defaulting on their credit card payment will in fact default?

# %% [markdown]
# Given that the *odds* is defined as:
# $$\text{odds} :=\frac{p(X)}{1-p(X)},$$
#
# --> *odds* = 0.37 means:
# $$0.37 = \frac{p(X)}{1-p(X)}\implies p(X) = 0.37-0.37p(X)\implies 1.37p(X) = 0.37\implies p(X) = \frac{0.37}{1.37}\approx \boxed{0.2701}$$

# %% [markdown]
# ###(b) Suppose that an individual has a $16 \%$ chance of defaulting on
# her credit card payment. What are the odds that she will default?

# %% [markdown]
# If our probability $p(X) = 16$, then it follows that:
# $$\text{odds} = \frac{0.16}{1-0.16} = \frac{0.16}{0.84} \approx \boxed{0.1905}$$
