# %% [markdown]
# ## ML&Fintech HW4 Chapter 4 Question 9
#
# Name: Alvin B. Lin\
# ID: 112652040\
# Date: 20/10/2025\
# HW #: 4

# %% [markdown]
# 9. This problem has to do with *odds*.

# %% [markdown]
# (a) On average, what fraction of people with an odds of 0.37 of
# defaulting on their credit card payment will in fact default?

# %% [markdown]
# Given that the *odds* is defined as:
# $$\text{odds} :=\frac{p(X)}{1-p(X)},$$
# where $X$ is the event and $p(X)\in [0,\;1)$ is the probability of the event happens.
#
# So if *odds* = 0.37, then it means that:
# $$0.37 = \frac{p(X)}{1-p(X)}\implies p(X) = 0.37-0.37p(X)\implies 0.63p(X) = 0.37\implies p(X) = \frac{0.37}{0.63}\approx \boxed{0.587}$$
#
# ---

# %% [markdown]
# (b) Suppose that an individual has a $16 \%$ chance of defaulting on
# her credit card payment. What are the odds that she will default?

# %% [markdown]
# If our probability $p(X) = 16$, then it follows that:
# $$\text{odds} = \frac{0.16}{1-0.16} = \frac{0.16}{0.84} \approx \boxed{0.1905}$$
