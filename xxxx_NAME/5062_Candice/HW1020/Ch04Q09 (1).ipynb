# %% [markdown]
# ### 9. This problem has to do with odds.
#
# ####(a) On average, what fraction of people with an odds of 0.37 of defaulting on their credit card payment will in fact default?

# %% [markdown]
# The relationship between odds and probability is:
#
# $$
# \text{odds} = \frac{p}{1 - p} \quad \Rightarrow \quad p = \frac{\text{odds}}{1 + \text{odds}}
# $$
#
# Substitute $\text{odds} = 0.37$:
#
# $$
# p = \frac{0.37}{1 + 0.37} = \frac{0.37}{1.37} \approx 0.2701
# $$
#
# About 27.01% of people will default.

# %% [markdown]
# ####(b) Suppose that an individual has a 16 % chance of defaulting on her credit card payment. What are the odds that she will default?

# %% [markdown]
# The formula for odds from probability is:
#
# $$
# \text{odds} = \frac{p}{1 - p}
# $$
#
# Substitute $p = 0.16$:
#
# $$
# \text{odds} = \frac{0.16}{1 - 0.16} = \frac{0.16}{0.84} \approx 0.1905
# $$
#
# The odds that she will default is 0.1905.
