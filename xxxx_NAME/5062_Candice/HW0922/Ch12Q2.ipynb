# %% [markdown]
# 2. Suppose that we have four observations, for which we compute a dissimilarity matrix, given by
# ![image.png](attachment:4999d8a5-6394-4f7b-b4fd-ad59524b1ce1.png)
#
# For instance, the dissimilarity between the first and second observations is 0.3, and the dissimilarity between the second and fourth observations is 0.8.
#
# (a) On the basis of this dissimilarity matrix, sketch the dendrogram that results from hierarchically clustering these four observations using complete linkage. Be sure to indicate on the plot the height at which each fusion occurs, as well as the observations corresponding to each leaf in the dendrogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch

D = np.array([
    [0.0, 0.3, 0.4, 0.7],
    [0.3, 0.0, 0.5, 0.8],
    [0.4, 0.5, 0.0, 0.45],
    [0.7, 0.8, 0.45, 0.0]
])

condensed_D = sch.distance.squareform(D) #SciPy的linkage函數不接受完整的方形矩陣，而是需要壓縮過的一維陣列（只取上三角）

# 做 complete linkage clustering
Z = sch.linkage(condensed_D, method="complete")

sch.dendrogram(Z, labels=["O1","O2","O3","O4"])
plt.title("Hierarchical Clustering Dendrogram (Complete Linkage)")
plt.xlabel("Observations")
plt.ylabel("Dissimilarity")
plt.show()

# %% [markdown]
# (b) Repeat (a), this time using single linkage clustering.

# %%
Z_single = sch.linkage(condensed_D, method="single")
sch.dendrogram(Z_single, labels=["O1","O2","O3","O4"])
plt.title("Hierarchical Clustering Dendrogram (Complete Linkage)")
plt.xlabel("Observations")
plt.ylabel("Dissimilarity")
plt.show()

# %% [markdown]
# (c) Suppose that we cut the dendrogram obtained in (a) such that two clusters result. Which observations are in each cluster?
#
# -> (O1,O2) (O3,O4)

# %% [markdown]
# (d) Suppose that we cut the dendrogram obtained in (b) such that two clusters result. Which observations are in each cluster?
#
# -> (O1,O2,O3) (O4)

# %% [markdown]
# (e) It is mentioned in this chapter that at each fusion in the dendrogram, the position of the two clusters being fused can be swapped without changing the meaning of the dendrogram. Draw a dendrogram that is equivalent to the dendrogram in (a), for which two or more of the leaves are repositioned, but for which the meaning of the dendrogram is the same.

# %%
sch.dendrogram(Z, labels=["O1","O2","O3","O4"], count_sort="descending")
plt.title("Equivalent Dendrogram (using count sort)")
plt.xlabel("Observations")
plt.ylabel("Dissimilarity")
plt.show()
