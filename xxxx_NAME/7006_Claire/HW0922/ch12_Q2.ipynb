# %% [markdown]
# Suppose that we have four observations, for which we compute a dissimilarity matrix, given by
# ![image.png](attachment:0c97d2b1-986b-48a3-8978-cd909f7e0d84.png)
# For instance, the dissimilarity between the first and second obser- vations is 0.3, and the dissimilarity between the second and fourth observations is 0.8.

# %% [markdown]
# ### (a)
# On the basis of this dissimilarity matrix, sketch the dendrogram that results from hierarchically clustering these four observa- tions using complete linkage. Be sure to indicate on the plot the height at which each fusion occurs, as well as the observations corresponding to each leaf in the dendrogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.spatial.distance import squareform

# %%
# dissimilarity matrix
D = np.array([
    [0,   0.3, 0.4, 0.7],
    [0.3, 0,   0.5, 0.8],
    [0.4, 0.5, 0,   0.45],
    [0.7, 0.8, 0.45, 0]
])

# scipy linkage expects condensed form (not full matrix)
D_condensed = squareform(D)

# complete linkage
Z_complete = linkage(D_condensed, method='complete')

plt.figure(figsize=(6,4))
dendrogram(Z_complete, labels=['Obs1','Obs2','Obs3','Obs4'])
plt.title('Complete Linkage Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Height')
plt.show()

# %% [markdown]
# ### (b)
# Repeat (a), this time using single linkage clustering.

# %%
Z_single = linkage(D_condensed, method='single')

plt.figure(figsize=(6,4))
dendrogram(Z_single, labels=['Obs1','Obs2','Obs3','Obs4'])
plt.title('Single Linkage Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Height')
plt.show()

# %% [markdown]
# ### (c)
# Suppose that we cut the dendrogram obtained in (a) such that two clusters result. Which observations are in each cluster?

# %%
clusters_complete = fcluster(Z_complete, t=2, criterion='maxclust')
print("(c) Two clusters under complete linkage:")
print(clusters_complete)
# Out:
# (c) Two clusters under complete linkage:
# [1 1 2 2]

# %% [markdown]
# ### (d)
# Suppose that we cut the dendrogram obtained in (b) such that two clusters result. Which observations are in each cluster?

# %%
clusters_single = fcluster(Z_single, t=2, criterion='maxclust')
print("(d) Two clusters under single linkage:")
print(clusters_single)
# Out:
# (d) Two clusters under single linkage:
# [1 1 1 2]

# %% [markdown]
# ### (e)
# It is mentioned in this chapter that at each fusion in the den- drogram, the position of the two clusters being fused can be swapped without changing the meaning of the dendrogram. Draw a dendrogram that is equivalent to the dendrogram in (a), for which two or more of the leaves are repositioned, but for which the meaning of the dendrogram is the same.

# %%
plt.figure(figsize=(6,4))
dendrogram(Z_complete, labels=['Obs3','Obs1','Obs2','Obs4'])
plt.title('Equivalent Complete Linkage Dendrogram (reordered)')
plt.xlabel('Observations (Reordered)')
plt.ylabel('Height')
plt.show()
