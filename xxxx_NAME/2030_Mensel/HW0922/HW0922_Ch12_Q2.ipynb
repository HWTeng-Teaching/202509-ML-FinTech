# %% [markdown]
# QUESTION NUMBER 2 PAGE 552 OF THE TEXTBOOK "AN INTRODUCTION TO STATISTICAL LEARNING WITH APPLICATIONS IN PYTHON".
#
# Suppose that we have four observations, for which we compute a
# dissimilarity matrix, given by
# [
# 0.0 0.3 0.4 0.7
# 0.3 0.0 0.5 0.8
# 0.4 0.5 0.0 0.45
# 0.7 0.8 0.45 0.0
# ]
#
# For instance, the dissimilarity between the first and second observations is 0.3, and the dissimilarity between the second and fourth
# observations is 0.8.

# %% [markdown]
# QUESTION A
#
# On the basis of this dissimilarity matrix, sketch the dendrogram that results from hierarchically clustering these four observations using complete linkage. Be sure to indicate on the plot the height at which each fusion occurs, as well as the observations corresponding to each leaf in the dendrogram.

# %%
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform
import matplotlib.pyplot as plt

# Step 1: Sample data (4 observations)
# Full symmetric distance matrix (redundant)
full_matrix = [
    [0.0, 0.3, 0.4, 0.7],
    [0.3, 0.0, 0.5, 0.8],
    [0.4, 0.5, 0.0, 0.45],
    [0.7, 0.8, 0.45, 0.0]
]

# Step 2: Convert to condensed distance matrix for linkage (scipy expects 1D condensed form)
# Order: (1,2), (1,3), (1,4), (2,3), (2,4), (3,4) and will result in: np.array([0.3, 0.4, 0.7, 0.5, 0.8, 0.45])

condensed_dist = squareform(full_matrix)

# Step 3: Compute linkage matrix (e.g., 'complete' or 'single')
Z = linkage(condensed_dist, method='complete')  # Try 'single', 'average', 'ward', etc.

# Step 4: Plot dendrogram
plt.figure(figsize=(8, 5))
dendrogram(Z, labels=["Obs 1", "Obs 2", "Obs 3", "Obs 4"])
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Observations")
plt.ylabel("Distance")
plt.show()

# %% [markdown]
# QUESTION B
#
# Repeat (a), this time using single linkage clustering.

# %%
# Step 1: Sample data (4 observations)
X = np.array([
    [0.3, 0.4, 0.7],
    [0.3, 0.5, 0.8],
    [0.4, 0.5, 0.45],
    [0.7, 0.8, 0.45]
])
# Step 2: Convert to condensed distance matrix for linkage (scipy expects 1D condensed form)
# Order: (1,2), (1,3), (1,4), (2,3), (2,4), (3,4)
condensed_dist = np.array([0.3, 0.4, 0.7, 0.5, 0.8, 0.45])

# Step 3: Compute linkage matrix (e.g., 'complete' or 'single')
Z = linkage(condensed_dist, method='single')  # Try 'single', 'average', 'ward', etc.

# Step 4: Plot dendrogram
plt.figure(figsize=(8, 5))
dendrogram(Z, labels=["Obs 1", "Obs 2", "Obs 3", "Obs 4"])
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Observations")
plt.ylabel("Distance")
plt.show()

# %% [markdown]
# QUESTION C
#
# Suppose that we cut the dendrogram obtained in (a) such that two clusters result. Which observations are in each cluster?
#
# Cluster 1: Observations 1 and 2
# Cluster 2: Observations 3 and 4

# %% [markdown]
# QUESTION D
#
# Suppose that we cut the dendrogram obtained in (b) such that two clusters result. Which observations are in each cluster?
#
# Cluster 1: Observations 1, 2, and 3
# Cluster 2: Observation 4

# %% [markdown]
# QUESTION E
#
# It is mentioned in this chapter that at each fusion in the dendrogram, the position of the two clusters being fused can be swapped without changing the meaning of the dendrogram. Draw a dendrogram that is equivalent to the dendrogram in (a), for which two or more of the leaves are repositioned, but for which the meaning of the dendrogram is the same.

# %%
# Step 2: Convert to condensed distance matrix for linkage (scipy expects 1D condensed form)
# Order: (1,2), (1,3), (1,4), (2,3), (2,4), (3,4)
condensed_dist = np.array([0.3, 0.4, 0.7, 0.5, 0.8, 0.45])

# Step 3: Compute linkage matrix (e.g., 'complete' or 'single')
Z = linkage(condensed_dist, method='complete')  # Try 'single', 'average', 'ward', etc.

# Step 4: Plot dendrogram
plt.figure(figsize=(8, 5))
dendrogram(Z, labels=["Obs 2", "Obs 1","Obs 4", "Obs 3"])
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Observations")
plt.ylabel("Distance")
plt.show()

# %% [markdown]
# You can switch the leaves of the observations within the cluster and nothing will happen.

# %%
# Step 2: Convert to condensed distance matrix for linkage (scipy expects 1D condensed form)
# Order: (1,2), (1,3), (1,4), (2,3), (2,4), (3,4)
condensed_dist = np.array([0.45, 0.8, 0.5, 0.7, 0.4, 0.3])

# Step 3: Compute linkage matrix (e.g., 'complete' or 'single')
Z = linkage(condensed_dist, method='complete')  # Try 'single', 'average', 'ward', etc.

# Step 4: Plot dendrogram
plt.figure(figsize=(8, 5))
dendrogram(Z, labels=["Obs 1", "Obs 2","Obs 3", "Obs 4"])
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Observations")
plt.ylabel("Distance")
plt.show()

# %% [markdown]
# You can switch the cluster within the dendograms below the cut that will make it into 2 clusters, and it will also not change the meaning or how we perceive and understand the data.
