# %% [markdown]
#  4. This question relates to the plots in Figure

# %% [markdown]
#                              X1 < 1?
#                            /         \
#                      Yes  /           \ No
#                          /             \
#                     X2 < 1?            Predict = 5
#                    /       \
#              Yes /         \ No
#                  /           \
#           Predict = 15     X2 < 0.5?
#                            /         \
#                      Yes /           \ No
#                          /             \
#                Predict = 3      Split by X2 < 0.5
#                                 /              \
#                         Predict = 10       Predict = 0

# %% [markdown]
#                            X2 < 1
#                           /      \
#                      Yes /        \ No
#                         /          \
#                     X1 < 1        X1 < 1
#                    /      \      /      \
#               -1.80      0.53  -1.06   X2 < 2
#                                         /    \
#                                       0.21   2.49
