# %% [markdown]
# #question_a
#
# On the basis of this dissimilarity matrix, sketch the dendrogram that results from hierarchically clustering these four observations using complete linkage. Be sure to indicate on the plot the height at which each fusion occurs, as well as the observations corresponding to each leaf in the dendrogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from ISLP.cluster import compute_linkage
from scipy.spatial.distance import squareform

matrix = np.array([
    [0.0, 0.3, 0.4, 0.7],
    [0.3, 0.0, 0.5, 0.8],
    [0.4, 0.5, 0.0, 0.45],
    [0.7, 0.8, 0.45, 0.0]
])

dist_vector = squareform(matrix)
Z = linkage(dist_vector, method='complete')

plt.figure(figsize=(6, 4))
dendrogram(Z, labels=['Obs1', 'Obs2', 'Obs3', 'Obs4'])
plt.ylabel('Dissimilarity')
plt.xlabel('Observations')
plt.title('Dendrogram for dissimilarity matrix (Complete Linkage)')
plt.show()

# %% [markdown]
# #question_b
# Repeat (a), this time using single linkage clustering.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from ISLP.cluster import compute_linkage
from scipy.spatial.distance import squareform

matrix = np.array([
    [0.0, 0.3, 0.4, 0.7],
    [0.3, 0.0, 0.5, 0.8],
    [0.4, 0.5, 0.0, 0.45],
    [0.7, 0.8, 0.45, 0.0]
])

dist_vector = squareform(matrix)
Z = linkage(dist_vector, method='single')

plt.figure(figsize=(6, 4))
dendrogram(Z, labels=['Obs1', 'Obs2', 'Obs3', 'Obs4'])
plt.ylabel('Dissimilarity')
plt.xlabel('Observations')
plt.title('Dendrogram for dissimilarity matrix (Single Linkage)')
plt.show()

# %% [markdown]
# #question_c
# Suppose that we cut the dendrogram obtained in (a) such that two clusters result. Which observations are in each cluster?
#
# **ans:** If we cut the dendrogram (a) to form two clusters, Obs1 and Obs2 are grouped into Cluster 1, whereas Obs3 and Obs4 belong to Cluster 2.

# %% [markdown]
# #question_d
# Suppose that we cut the dendrogram obtained in (b) such that two clusters result. Which observations are in each cluster?
#
# **ans:** When the dendrogram (b) is divided into two clusters, Obs1, Obs2, and Obs3 fall into Cluster 1, while Obs4 is assigned to Cluster 2.

# %% [markdown]
# #question_e
# It is mentioned in this chapter that at each fusion in the dendrogram, the position of the two clusters being fused can be swapped without changing the meaning of the dendrogram. Draw a dendrogram that is equivalent to the dendrogram in (a), for which two or more of the leaves are repositioned, but for which the meaning of the dendrogram is the same.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from ISLP.cluster import compute_linkage
from scipy.spatial.distance import squareform

matrix = np.array([
    [0.0, 0.3, 0.4, 0.7],
    [0.3, 0.0, 0.5, 0.8],
    [0.4, 0.5, 0.0, 0.45],
    [0.7, 0.8, 0.45, 0.0]
])

dist_vector = squareform(matrix)
Z = linkage(dist_vector, method='complete')

plt.figure(figsize=(6, 4))
dendrogram(Z, labels=['Obs2', 'Obs1', 'Obs4', 'Obs3'])
plt.ylabel('Dissimilarity')
plt.xlabel('Observations')
plt.title('Dendrogram for dissimilarity matrix (Complete Linkage)')
plt.show()
