# %% [markdown]
# ### Question 4
# This question relates to the plots in Figure 8.14

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
