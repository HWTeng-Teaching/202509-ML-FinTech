# %% [markdown]
# On the basis of this dissimilarity matrix, sketch the dendrogram
# that results from hierarchically clustering these four observations using complete linkage. Be sure to indicate on the plot the
# height at which each fusion occurs, as well as the observations
# corresponding to each leaf in the dendrogram.

# %%
import numpy as np
from scipy.cluster.hierarchy import linkage, leaves_list, dendrogram
from scipy.spatial.distance import squareform
import matplotlib.pyplot as plt

# %%
D = np.array([
    [0.0, 0.30, 0.40, 0.70],
    [0.30, 0.0, 0.50, 0.80],
    [0.40, 0.50, 0.0, 0.45],
    [0.70, 0.80, 0.45, 0.0]
])

# %%
dists = squareform(D, checks=True)

linkage_matrix = linkage(dists, method='complete')

fig, ax = plt.subplots(figsize=(6, 4))
dendrogram(linkage_matrix, labels=['1', '2', '3', '4'], orientation='top', ax=ax)
ax.set_title('Complete Linkage Hierarchical Clustering')
ax.set_ylabel('Dissimilarity')
for h in [0.30, 0.45, 0.80]:
    ax.axhline(h, color='gray', linestyle='--', linewidth=0.7)
plt.show()

print("\nLinkage matrix", linkage_matrix)
# Out:
# Linkage matrix [[0.   1.   0.3  2.  ]
#  [2.   3.   0.45 2.  ]
#  [4.   5.   0.8  4.  ]]

# %% [markdown]
# Repeat (a), this time using single linkage clustering.

# %%
Z_single = linkage(dists, method='single')

fig2, ax2 = plt.subplots(figsize=(6, 4))
dendrogram(Z_single, labels=['1', '2', '3', '4'], orientation='top', ax=ax2, color_threshold=0.5)
ax2.set_title('Single Linkage Hierarchical Clustering')
ax2.set_ylabel('Dissimilarity')
for thresh in [0.30, 0.40, 0.45]:
    ax2.hlines(thresh, xmin=0, xmax=3, colors='purple', linestyles='dotted', linewidth=1)
plt.tight_layout()
plt.show()

print("\nSingle linkage matrix (idx1, idx2, height, sample_count):")
print(Z_single)
# Out:
# Single linkage matrix (idx1, idx2, height, sample_count):
# [[0.   1.   0.3  2.  ]
#  [2.   4.   0.4  3.  ]
#  [3.   5.   0.45 4.  ]]

# %% [markdown]
# Suppose that we cut the dendrogram obtained in (a) such that two clusters result. Which observations are in each cluster?

# %% [markdown]
# 1: [1,2]
# 2: [3,4]

# %% [markdown]
# Suppose that we cut the dendrogram obtained in (b) such that two clusters result. Which observations are in each cluster?

# %% [markdown]
# 1: [1,2,3]
# 2: [4]

# %% [markdown]
# It is mentioned in this chapter that at each fusion in the dendrogram, the position of the two clusters being fused can be swapped without changing the meaning of the dendrogram. Draw a dendrogram that is equivalent to the dendrogram in (a), for which two or more of the leaves are repositioned, but for which the meaning of the dendrogram is the same.

# %%
fig3, ax3 = plt.subplots(figsize=(6, 4))
dendrogram(linkage_matrix, labels=['4', '3', '2', '1'], orientation='top', ax=ax3)
ax3.set_title('Equivalent Complete Linkage Dendrogram (Reordered)')
ax3.set_ylabel('Dissimilarity')
for h in [0.30, 0.45, 0.80]:
    ax3.axhline(h, color='lightblue', linestyle=':', linewidth=1)
plt.tight_layout()
plt.show()
