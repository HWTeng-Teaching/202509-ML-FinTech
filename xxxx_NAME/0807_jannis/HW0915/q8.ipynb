# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Task a
# Load dataset into python

# %%
college = pd.read_csv("data/College.csv")

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = pd.read_csv("data/College.csv", index_col=0)
college3 = college.rename({"Unnamed: 0":"College"},
                          axis=1)
college3 = college3.set_index("College")

# %%
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college = college3
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# c)

# %%
description = college.describe()
description
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# d)

# %%
pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# e)

# %%
college.boxplot("Outstate", "Private")
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# f)

# %%
college["Elite"] = pd.cut(college["Top10perc"],
                          [0,50, 100],
                          labels=["No", "Yes"])

college["Elite"].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college.boxplot("Outstate", "Elite")
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# g)

# %%
fig, ax = plt.subplots(2,2)
college["Top10perc"].plot.hist(ax=ax[0,0], bins=20).set_title("Top10perc")
college["Outstate"].plot.hist(ax=ax[0,1], bins=50).set_title("Outstate")
college["Apps"].plot.hist(ax=ax[1,0], bins=100).set_title("Apps")
college["Enroll"].plot.hist(ax=ax[1,1], bins=10).set_title("Enroll")

plt.tight_layout()
plt.show()

# %%
college.boxplot("Top10perc", "Private")
# Out:
# <Axes: title={'center': 'Top10perc'}, xlabel='Private'>

# %% [markdown]
# => private have more top10perc students. Both have a lot of outliers

# %%
college.boxplot("Books", "Private")
college.boxplot("Personal", "Private")
college.boxplot("PhD", "Private")
college.boxplot("Expend", "Private")
college.boxplot("Room.Board", "Private")
college.boxplot("Grad.Rate", "Private")
# Out:
# <Axes: title={'center': 'Grad.Rate'}, xlabel='Private'>

# %% [markdown]
# => private unis have a higher grad.rate. Also there seem to be a couple of private unis which grad.rate lie significantly below the others
# => Room.Board seems to be higher in private unis
# => a lot of outliers in the expends for the private unis => a few very expensive private universities

# %%
college["Accept.rate"] = college["Accept"] / college["Apps"]
college.boxplot("Accept.rate", "Private")
pd.plotting.scatter_matrix(college[["Accept.rate", "Expend"]])
# Out:
# array([[<Axes: xlabel='Accept.rate', ylabel='Accept.rate'>,
#         <Axes: xlabel='Expend', ylabel='Accept.rate'>],
#        [<Axes: xlabel='Accept.rate', ylabel='Expend'>,
#         <Axes: xlabel='Expend', ylabel='Expend'>]], dtype=object)

# %% [markdown]
# => private unis have more outliers => way more highly selective private unis
# => No correlation apparent!

# %%
pd.plotting.scatter_matrix(college[["F.Undergrad", "Expend"]])
# Out:
# array([[<Axes: xlabel='F.Undergrad', ylabel='F.Undergrad'>,
#         <Axes: xlabel='Expend', ylabel='F.Undergrad'>],
#        [<Axes: xlabel='F.Undergrad', ylabel='Expend'>,
#         <Axes: xlabel='Expend', ylabel='Expend'>]], dtype=object)

# %% [markdown]
# => slight correlation?

# %%
college["Elite"].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college[(college['Private'] == 'Yes') & (college['Elite'] == 'Yes')].shape[0]
# Out:
# 65

# %%
college[(college['Private'] == 'No') & (college['Elite'] == 'Yes')].shape[0]
# Out:
# 13

# %% [markdown]
# # Summary
# + Nearly all elite university are also private universities
# + Personal expenses are slightly lower in private universities, but there are also a lot of outliers
# + private unis have a higher grad.rate. Also there seem to be a couple of private unis which grad.rate lie significantly below the others
# + Room.Board seems to be higher in private unis
# + a lot of outliers in the expends for the private unis => a few very expensive private universities
# + private unis have more outliers in acceptance rate => way more highly selective private unis
