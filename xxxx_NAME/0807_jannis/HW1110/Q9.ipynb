# %% [markdown]
# Based on this data set, provide an estimate for the population
# mean of medv. Call this estimate µˆ.

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from ISLP import load_data
import pandas as pd
from ISLP.models import (ModelSpec as MS,
summarize,
poly)
from sklearn.model_selection import train_test_split
from functools import partial
from sklearn.model_selection import \
(cross_validate,
KFold,
ShuffleSplit)
from sklearn.base import clone
from ISLP.models import sklearn_sm

# %%
boston = load_data("Boston")
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
myu_h = boston["medv"].mean()
myu_h
# Out:
# np.float64(22.532806324110677)

# %%
sde = boston["medv"].std() / np.sqrt(boston.shape[0])
sde
# Out:
# np.float64(0.40886114749753505)

# %%
bs_means = []
for _ in range(10000):
    sample = np.random.choice(boston["medv"].values, size=boston.shape[0], replace=True)
    bs_means.append(np.mean(sample))

sde = np.std(bs_means)
sde
# Out:
# np.float64(0.41143556857236396)

# %% [markdown]
# Very close to b)

# %% [markdown]
# Based on your bootstrap estimate from (c), provide a 95 % confidence interval for the mean of medv. Compare it to the results
# obtained by using Boston['medv'].std() and the two standard
# error rule (3.9).
# Hint: You can approximate a 95 % confidence interval using the
# formula [ˆµ − 2SE(ˆµ), µˆ + 2SE(ˆµ)].

# %%
(myu - 2*sde, myu + 2*sde)
# Out:
# (np.float64(21.72400490397887), np.float64(23.341607744242484))

# %% [markdown]
# (e) Based on this data set, provide an estimate, µˆmed, for the median
# value of medv in the population.

# %%
med = boston["medv"].median()
med
# Out:
# np.float64(21.2)

# %%
bs_medians = []
for _ in range(10000):
    sample = np.random.choice(boston["medv"].values, size=boston.shape[0], replace=True)
    bs_medians.append(np.median(sample))

sde_med = np.std(bs_medians)
sde_med
# Out:
# np.float64(0.3831343595920363)

# %% [markdown]
# The estimated SDE is quite small, therefore our estimator seems to to a good job

# %% [markdown]
# ) Based on this data set, provide an estimate for the tenth percentile of medv in Boston census tracts. Call this quantity µˆ0.1.
# (You can use the np.percentile() function.)

# %%
perc10 = np.percentile(boston["medv"], 10)
perc10
# Out:
# np.float64(12.75)

# %% [markdown]
# Use the bootstrap to estimate the standard error of µˆ0.1. Comment on your findings.

# %%
bs_perc = []
for _ in range(10000):
    sample = np.random.choice(boston["medv"].values, size=boston.shape[0], replace=True)
    bs_perc.append(sample)

sde_perc = np.std(bs_perc)
sde_perc
# Out:
# np.float64(9.18716538747883)

# %% [markdown]
# The SDE is pretty high, suggesting our estimation of the lower 10. percentile is not accurate
